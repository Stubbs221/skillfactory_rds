# %%
# Libraries
from scipy import stats
from scipy.stats import ttest_ind
from itertools import combinations
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data exploration

# %%
stud = pd.read_csv('stud_math.csv')

# %%
# functions
def iqr(column):
    IQR = column.quantile(0.75) - column.quantile(0.25)
    perc25 = column.quantile(0.25)
    perc75 = column.quantile(0.75)
    print(
        '25-й перцентиль: {},'.format(perc25),
        '75-й перцентиль: {},'.format(perc75),
        "IQR: {}, ".format(IQR),
        "Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
    column.loc[column.between(
        perc25 - 1.5*IQR,
        perc75 + 1.5*IQR)].hist(bins=16, range=(40, 100), label='IQR')
    column.loc[column <= 100].hist(
        alpha=0.5, bins=16, range=(40, 100), label='Здравый смысл')
    plt.legend()


def none_to_m(df):  # convert None values to mean if variable type is quantitative and to mode if qualitative
    for column in df.columns:
        if (df[column].dtype == np.float64) | (df[column].dtype == np.int64):
            df[column] = df[column].fillna(round(df[column].mean()))
        elif (df[column].dtype == np.object):
            df[column] = df[column].fillna(df[column].mode()[0])

def get_boxplot(df)
            
def describe_all(df):  # function to describe all columns in DataFrame
    for column in df.columns:
        display(df[column].describe())

# %%
display(stud.head(10))
stud.info()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  ...  \
# 0     GP   F   18       U     NaN       A   4.0   4.0   at_home  teacher  ...
# 1     GP   F   17       U     GT3     NaN   1.0   1.0   at_home    other  ...
# 2     GP   F   15       U     LE3       T   1.0   1.0   at_home    other  ...
# 3     GP   F   15       U     GT3       T   4.0   2.0    health      NaN  ...
# 4     GP   F   16       U     GT3       T   3.0   3.0     other    other  ...
# 5     GP   M   16       U     LE3       T   4.0   3.0  services    other  ...
# 6     GP   M   16     NaN     LE3       T   2.0   2.0     other    other  ...
# 7     GP   F   17       U     GT3       A   4.0   4.0     other  teacher  ...
# 8     GP   M   15       U     LE3       A   3.0   2.0  services    other  ...
# 9     GP   M   15       U     NaN     NaN   3.0   4.0     other    other  ...
#
#   studytime, granular higher  internet  romantic  famrel freetime goout  \
# 0                -6.0    yes       NaN        no     4.0      3.0   4.0
# 1                -6.0    yes       yes        no     5.0      3.0   3.0
# 2                -6.0    yes       yes       NaN     4.0      3.0   2.0
# 3                -9.0    yes       yes       yes     3.0      2.0   2.0
# 4                -6.0    yes        no        no     4.0      3.0   2.0
# 5                -6.0    yes       yes        no     5.0      4.0   2.0
# 6                -6.0    yes       yes        no     4.0      4.0   4.0
# 7                -6.0    yes        no        no     4.0      1.0   4.0
# 8                -6.0    yes       yes        no     NaN      2.0   2.0
# 9                -6.0    yes       yes        no     5.0      5.0   1.0
#
#   health absences score
# 0    3.0      6.0  30.0
# 1    3.0      4.0  30.0
# 2    3.0     10.0  50.0
# 3    5.0      2.0  75.0
# 4    5.0      4.0  50.0
# 5    5.0     10.0  75.0
# 6    3.0      0.0  55.0
# 7    1.0      6.0  30.0
# 8    1.0      0.0  95.0
# 9    5.0      0.0  75.0
#
# [10 rows x 30 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   school               395 non-null    object
#  1   sex                  395 non-null    object
#  2   age                  395 non-null    int64
#  3   address              378 non-null    object
#  4   famsize              368 non-null    object
#  5   Pstatus              350 non-null    object
#  6   Medu                 392 non-null    float64
#  7   Fedu                 371 non-null    float64
#  8   Mjob                 376 non-null    object
#  9   Fjob                 359 non-null    object
#  10  reason               378 non-null    object
#  11  guardian             364 non-null    object
#  12  traveltime           367 non-null    float64
#  13  studytime            388 non-null    float64
#  14  failures             373 non-null    float64
#  15  schoolsup            386 non-null    object
#  16  famsup               356 non-null    object
#  17  paid                 355 non-null    object
#  18  activities           381 non-null    object
#  19  nursery              379 non-null    object
#  20  studytime, granular  388 non-null    float64
#  21  higher               375 non-null    object
#  22  internet             361 non-null    object
#  23  romantic             364 non-null    object
#  24  famrel               368 non-null    float64
#  25  freetime             384 non-null    float64
#  26  goout                387 non-null    float64
#  27  health               380 non-null    float64
#  28  absences             383 non-null    float64
#  29  score                389 non-null    float64
# dtypes: float64(12), int64(1), object(17)
# memory usage: 92.7+ KB

# %% [markdown]
#  So there are 13 numerical variables and 17 categorial. And some missing values

# %%
describe_all(stud)
# Out:
# count     395
# unique      2
# top        GP
# freq      349
# Name: school, dtype: object
# count     395
# unique      2
# top         F
# freq      208
# Name: sex, dtype: object
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64
# count     378
# unique      2
# top         U
# freq      295
# Name: address, dtype: object
# count     368
# unique      2
# top       GT3
# freq      261
# Name: famsize, dtype: object
# count     350
# unique      2
# top         T
# freq      314
# Name: Pstatus, dtype: object
# count    392.000000
# mean       2.750000
# std        1.098127
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Medu, dtype: float64
# count    371.000000
# mean       2.614555
# std        2.228732
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max       40.000000
# Name: Fedu, dtype: float64
# count       376
# unique        5
# top       other
# freq        133
# Name: Mjob, dtype: object
# count       359
# unique        5
# top       other
# freq        197
# Name: Fjob, dtype: object
# count        378
# unique         4
# top       course
# freq         137
# Name: reason, dtype: object
# count        364
# unique         3
# top       mother
# freq         250
# Name: guardian, dtype: object
# count    367.000000
# mean       1.438692
# std        0.694181
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        4.000000
# Name: traveltime, dtype: float64
# count    388.000000
# mean       2.038660
# std        0.842078
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000
# Name: studytime, dtype: float64
# count    373.000000
# mean       0.337802
# std        0.743135
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: failures, dtype: float64
# count     386
# unique      2
# top        no
# freq      335
# Name: schoolsup, dtype: object
# count     356
# unique      2
# top       yes
# freq      219
# Name: famsup, dtype: object
# count     355
# unique      2
# top        no
# freq      200
# Name: paid, dtype: object
# count     381
# unique      2
# top       yes
# freq      195
# Name: activities, dtype: object
# count     379
# unique      2
# top       yes
# freq      300
# Name: nursery, dtype: object
# count    388.000000
# mean      -6.115979
# std        2.526235
# min      -12.000000
# 25%       -6.000000
# 50%       -6.000000
# 75%       -3.000000
# max       -3.000000
# Name: studytime, granular, dtype: float64
# count     375
# unique      2
# top       yes
# freq      356
# Name: higher, dtype: object
# count     361
# unique      2
# top       yes
# freq      305
# Name: internet, dtype: object
# count     364
# unique      2
# top        no
# freq      240
# Name: romantic, dtype: object
# count    368.000000
# mean       3.937500
# std        0.927277
# min       -1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: famrel, dtype: float64
# count    384.000000
# mean       3.231771
# std        0.993940
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: freetime, dtype: float64
# count    387.000000
# mean       3.105943
# std        1.115896
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: goout, dtype: float64
# count    380.000000
# mean       3.531579
# std        1.396019
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# Name: health, dtype: float64
# count    383.000000
# mean       7.279373
# std       23.465197
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64
# count    389.000000
# mean      52.262211
# std       22.919022
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %% [markdown]
# On the cell above we can see that columns 'Fedu' and 'famrel' has incorrect data.

# %%
#

stud.loc[stud.Fedu == '40.0', 'Fedu'] = 4.0
stud.loc[stud.famrel == '-1.0', 'famrel'] = stud.famrel.mean()

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.histplot(stud.absences)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-304-02db7bb0c917> in <module>
#       1 fig, ax = plt.subplots(figsize=(14,8))
# ----> 2 sns.histplot(stud.absences)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'absences'

# %% [markdown]
# Only few students were absent more than 50 times. Lets drop values which is more than 50

# %%
stud = stud.absences[np.abs(stats.zscore(stud.absences)) < 3]

# %%
stud
# Out:
# 0       6.0
# 1       4.0
# 2      10.0
# 3       2.0
# 4       4.0
#        ...
# 389     0.0
# 391     3.0
# 392     3.0
# 393     0.0
# 394     5.0
# Name: absences, Length: 393, dtype: float64

# %%
#converting NaN into mean and mode

none_to_m(stud)
stud.head(50)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A   4.0   4.0   at_home   teacher
# 1      GP   F   17       U     GT3       T   1.0   1.0   at_home     other
# 2      GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3      GP   F   15       U     GT3       T   4.0   2.0    health     other
# 4      GP   F   16       U     GT3       T   3.0   3.0     other     other
# 5      GP   M   16       U     LE3       T   4.0   3.0  services     other
# 6      GP   M   16       U     LE3       T   2.0   2.0     other     other
# 7      GP   F   17       U     GT3       A   4.0   4.0     other   teacher
# 8      GP   M   15       U     LE3       A   3.0   2.0  services     other
# 9      GP   M   15       U     GT3       T   3.0   4.0     other     other
# 10     GP   F   15       U     GT3       T   4.0   4.0   teacher    health
# 11     GP   F   15       U     GT3       T   2.0  40.0  services     other
# 12     GP   M   15       U     LE3       T   4.0   4.0    health  services
# 13     GP   M   15       U     GT3       T   4.0   3.0   teacher     other
# 14     GP   M   15       U     GT3       A   2.0   2.0     other     other
# 15     GP   F   16       U     GT3       T   4.0   4.0    health     other
# 16     GP   F   16       U     GT3       T   4.0   4.0  services  services
# 17     GP   F   16       U     GT3       T   3.0   3.0     other     other
# 18     GP   M   17       U     GT3       T   3.0   2.0  services  services
# 19     GP   M   16       U     LE3       T   4.0   3.0    health     other
# 20     GP   M   15       U     GT3       T   4.0   3.0   teacher     other
# 21     GP   M   15       U     GT3       T   4.0   3.0    health    health
# 22     GP   M   16       U     LE3       T   4.0   2.0   teacher     other
# 23     GP   M   16       U     LE3       T   2.0   2.0     other     other
# 24     GP   F   15       R     GT3       T   2.0   4.0  services    health
# 25     GP   F   16       U     GT3       T   2.0   2.0  services  services
# 26     GP   M   15       U     GT3       T   2.0   2.0     other     other
# 27     GP   M   15       U     GT3       T   4.0   2.0    health  services
# 28     GP   M   16       U     LE3       T   3.0   4.0  services     other
# 29     GP   M   16       U     GT3       T   4.0   4.0     other   teacher
# 30     GP   M   15       U     GT3       T   4.0   4.0    health  services
# 31     GP   M   15       U     GT3       T   4.0   4.0  services     other
# 32     GP   M   15       R     GT3       T   4.0   3.0   teacher   at_home
# 33     GP   M   15       U     LE3       T   3.0   3.0     other     other
# 34     GP   M   16       U     GT3       T   3.0   2.0     other     other
# 35     GP   F   15       U     GT3       T   2.0   3.0     other     other
# 36     GP   M   15       U     GT3       T   4.0   3.0   teacher  services
# 37     GP   M   16       R     GT3       A   4.0   4.0     other   teacher
# 38     GP   F   15       R     GT3       T   3.0   4.0  services    health
# 39     GP   F   15       R     GT3       T   2.0   2.0   at_home     other
# 40     GP   F   16       U     LE3       T   2.0   2.0     other     other
# 41     GP   M   15       U     LE3       T   4.0   4.0   teacher     other
# 42     GP   M   15       U     GT3       T   4.0   3.0  services   teacher
# 43     GP   M   15       U     GT3       T   2.0   2.0  services  services
# 44     GP   F   16       U     LE3       T   2.0   2.0     other     other
# 45     GP   F   15       U     LE3       A   4.0   3.0     other     other
# 46     GP   F   16       U     LE3       A   3.0   3.0     other  services
# 47     GP   M   16       U     GT3       T   4.0   3.0    health     other
# 48     GP   M   15       U     GT3       T   4.0   2.0   teacher     other
# 49     GP   F   15       U     GT3       T   4.0   4.0  services   teacher
#
#     ... studytime, granular higher  internet  romantic  famrel freetime goout  \
# 0   ...                -6.0    yes       yes        no     4.0      3.0   4.0
# 1   ...                -6.0    yes       yes        no     5.0      3.0   3.0
# 2   ...                -6.0    yes       yes        no     4.0      3.0   2.0
# 3   ...                -9.0    yes       yes       yes     3.0      2.0   2.0
# 4   ...                -6.0    yes        no        no     4.0      3.0   2.0
# 5   ...                -6.0    yes       yes        no     5.0      4.0   2.0
# 6   ...                -6.0    yes       yes        no     4.0      4.0   4.0
# 7   ...                -6.0    yes        no        no     4.0      1.0   4.0
# 8   ...                -6.0    yes       yes        no     4.0      2.0   2.0
# 9   ...                -6.0    yes       yes        no     5.0      5.0   1.0
# 10  ...                -6.0    yes       yes        no     3.0      3.0   3.0
# 11  ...                -9.0    yes       yes        no     5.0      2.0   2.0
# 12  ...                -3.0    yes       yes        no     4.0      3.0   3.0
# 13  ...                -6.0    yes       yes        no     5.0      4.0   3.0
# 14  ...                -9.0    yes       yes       yes     4.0      5.0   2.0
# 15  ...                -3.0    yes       yes        no     4.0      4.0   4.0
# 16  ...                -9.0    yes       yes        no     3.0      2.0   3.0
# 17  ...                -6.0    yes        no        no     5.0      3.0   2.0
# 18  ...                -3.0    yes       yes        no     5.0      5.0   5.0
# 19  ...                -3.0    yes       yes        no     3.0      1.0   3.0
# 20  ...                -6.0    yes       yes        no     4.0      4.0   1.0
# 21  ...                -3.0    yes       yes        no     5.0      4.0   2.0
# 22  ...                -6.0    yes       yes        no     4.0      5.0   1.0
# 23  ...                -6.0    yes       yes        no     5.0      4.0   4.0
# 24  ...                -9.0    yes       yes        no     4.0      3.0   2.0
# 25  ...                -3.0    yes       yes        no    -1.0      2.0   2.0
# 26  ...                -3.0    yes       yes        no     4.0      2.0   2.0
# 27  ...                -3.0    yes       yes        no     2.0      2.0   4.0
# 28  ...                -6.0    yes       yes        no     5.0      3.0   3.0
# 29  ...                -6.0    yes       yes       yes     4.0      4.0   5.0
# 30  ...                -6.0    yes       yes        no     5.0      4.0   2.0
# 31  ...                -6.0    yes       yes        no     4.0      3.0   1.0
# 32  ...                -6.0    yes       yes       yes     4.0      3.0   2.0
# 33  ...                -6.0    yes       yes        no     5.0      3.0   2.0
# 34  ...                -3.0    yes       yes        no     5.0      4.0   3.0
# 35  ...                -3.0    yes        no        no     3.0      5.0   1.0
# 36  ...                -9.0    yes       yes        no     5.0      4.0   3.0
# 37  ...                -9.0    yes       yes       yes     2.0      4.0   3.0
# 38  ...                -9.0    yes       yes        no     4.0      3.0   2.0
# 39  ...                -3.0    yes        no        no     4.0      3.0   1.0
# 40  ...                -6.0    yes       yes       yes     3.0      3.0   3.0
# 41  ...                -3.0    yes       yes        no     5.0      4.0   3.0
# 42  ...                -6.0    yes       yes        no     4.0      3.0   3.0
# 43  ...                -3.0    yes       yes        no     4.0      4.0   1.0
# 44  ...                -6.0    yes       yes        no     4.0      3.0   3.0
# 45  ...                -6.0    yes       yes       yes     5.0      2.0   2.0
# 46  ...                -6.0    yes       yes        no     2.0      3.0   5.0
# 47  ...               -12.0    yes       yes        no     4.0      2.0   2.0
# 48  ...                -6.0    yes        no        no     4.0      3.0   3.0
# 49  ...                -6.0    yes       yes        no     4.0      4.0   4.0
#
#    health absences  score
# 0     3.0      6.0   30.0
# 1     3.0      4.0   30.0
# 2     3.0     10.0   50.0
# 3     5.0      2.0   75.0
# 4     5.0      4.0   50.0
# 5     5.0     10.0   75.0
# 6     3.0      0.0   55.0
# 7     1.0      6.0   30.0
# 8     1.0      0.0   95.0
# 9     5.0      0.0   75.0
# 10    2.0      0.0   45.0
# 11    4.0      4.0   60.0
# 12    5.0      2.0   70.0
# 13    3.0      2.0   55.0
# 14    3.0      0.0   80.0
# 15    2.0      4.0   70.0
# 16    2.0      6.0   70.0
# 17    4.0      4.0   50.0
# 18    5.0     16.0   25.0
# 19    5.0      4.0   50.0
# 20    1.0      0.0   75.0
# 21    5.0      0.0   75.0
# 22    5.0      2.0   80.0
# 23    5.0      0.0   60.0
# 24    5.0      7.0   40.0
# 25    5.0     14.0   40.0
# 26    5.0      2.0   55.0
# 27    1.0      4.0   75.0
# 28    5.0      4.0   55.0
# 29    5.0     16.0   55.0
# 30    4.0      0.0   60.0
# 31    5.0      0.0   85.0
# 32    5.0      0.0   80.0
# 33    2.0      0.0   60.0
# 34    5.0      0.0   75.0
# 35    5.0      0.0   30.0
# 36    4.0      2.0   90.0
# 37    5.0      7.0   75.0
# 38    5.0      2.0   55.0
# 39    2.0      8.0   65.0
# 40    3.0     25.0   55.0
# 41    5.0      8.0   60.0
# 42    5.0      2.0   90.0
# 43    1.0      0.0   55.0
# 44    5.0     14.0   45.0
# 45    5.0      8.0   30.0
# 46    3.0     12.0   55.0
# 47    2.0      4.0  100.0
# 48    5.0      2.0   70.0
# 49    3.0      2.0   35.0
#
# [50 rows x 30 columns]

# %%
stud.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score'],
#       dtype='object')

# %% [markdown]
# 'studytime' and 'studytime_granular' has almost similar name. Let's make scatterplot to see it's correlation

# %%
stud = stud.rename(columns={'studytime, granular': 'studytime_granular'})

fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1])
axes.scatter(x=stud['studytime'], y=stud['studytime_granular'], marker='o')
axes.set_title('studytime VS studytime_granular')
axes.set_xlabel('studytime')
axes.set_ylabel('studytime_granular')
# Out:
# Text(0, 0.5, 'studytime_granular')

# %% [markdown]
# 'studytime' and 'studytime_granular' has the same count of values and negative correlation. Lets drop 'studytime_granular' because of useless values

# %%
stud.drop(['studytime_granular'], inplace=True, axis=1)

# %%
pd.DataFrame(stud.school.value_counts())
# Out:
#     school
# GP     349
# MS      46

# %% [markdown]
# Here we can see that only 2 schools took part in reserch

# %%
correlation = stud.corr()

fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(correlation, annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# So here we can see that 'score' has negative weak correlation with 'Medu' and negative moderate correlation with 'failures'
